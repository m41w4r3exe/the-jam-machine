# %% [markdown]
# # Play MIDI file

# %%
# import packages from one directory up
import sys
sys.path.append('../')
from source.playback import get_music, show_piano_roll
from IPython.display import Audio
from pathlib import Path

# load the midi file you want to play
midi_input = '/Users/louis.demetz/Documents/Code/the-jam-machine/midi/generated/JammyMachina/elec-gmusic-familized-model-13-12__17-35-53/20221214_145751.mid'

# get the PrettyMIDI object and the audio signal and play the audio
music_notes, waveform = get_music(midi_input)
Audio(waveform, rate=44100.0)
# Out:
# fluidsynth: error: Unknown integer parameter 'synth.sample-rate'
# fluidsynth: error: There is no preset with bank number 128 and preset number 5 in SoundFont 1
# fluidsynth: error: Unknown integer parameter 'synth.sample-rate'
# fluidsynth: error: Unknown integer parameter 'synth.sample-rate'
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# from source.utils import write_mp3

# output_path = source_path / (midi_input.stem + '.mp3')
# write_mp3(waveform, output_path, bitrate="92k")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[844], line 3
#       1 from source.utils import write_mp3
# ----> 3 output_path = source_path / (midi_input.stem + '.mp3')
#       4 write_mp3(waveform, output_path, bitrate="92k")
#
# AttributeError: 'str' object has no attribute 'stem'

# %% [markdown]
# # Display the piano roll

# %%
show_piano_roll(music_notes, fs=100)
# Out:
# Piano roll shape: (128, 1600)
# /Users/louis.demetz/miniforge3/envs/jam/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: Frequency axis exceeds Nyquist. Did you remember to set all spectrogram parameters in specshow?
#   return f(*args, **kwargs)
